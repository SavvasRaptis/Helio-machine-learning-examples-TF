# %% [markdown]
# # Initialization
#
# ## Importing libraries
#
# As a first step we load the different libraries we are going to use, in this simple example we only need tensorflow (keras) and numpy

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import backend as K
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense,Input
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import BatchNormalization,Dropout,Flatten, MaxPooling2D, Conv2D
from tensorflow.keras.layers import LeakyReLU,PReLU,ELU,ThresholdedReLU,ReLU
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Loading Data
#
# Next step is to actually load the Cifar10 database and perform some simple pre-process in order to introduce it to the neural network

# %%
# Parameters of the model 
num_classes = 10 # number of output class (1-9)

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data() # we load the data from keras.datsets library

# Normalize pixel values to be between 0 and 1
## Normalization ##
# Scale images to the [0, 1] range
x_train = x_train / 255 # images are encoded with up to 256 so to normalize from 0-1 we simply divide
x_test = x_test / 255

print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## Visualize the dataset

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    random_image = random.randint(1, 50000)
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[random_image])
    plt.xlabel(class_names[y_train[random_image][0]])
plt.show()

# %% [markdown]
# ## Model related parameters
#
# Here we define hyperparameters that are going to be used in the model and training below

# %%
n_epochs = 25 # Number of epochs, where 1 epoch = 1 use of the training set
n_batch_size = 256 # how many inputs are going to be used at the same time during one epoch. 
# note: small batch size can make the training faster but can make the generalization harder to achieve (less variety in sample)

neurons_conv2d1 = 32
kernel_size_conv2d1 = (3,3)
neurons_conv2d2 = 64
kernel_size_conv2d2 = (3,3)
neurons_conv2d3 = 128
kernel_size_conv2d3 = (3,3)
default_pool_size = (2,2)

# number of neurons for the 1 hidden layers
neurons_l1 = 600
neurons_l2 = 300
neurons_l3 = 150

# %%
model = keras.Sequential()
model.add(Conv2D(neurons_conv2d1,kernel_size=kernel_size_conv2d1,input_shape=(32, 32, 3))) # obtaining features from image
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(Conv2D(neurons_conv2d2,kernel_size_conv2d2, strides =2))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(Conv2D(neurons_conv2d3,kernel_size_conv2d3, strides =2))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(LeakyReLU())
model.add(layers.Flatten())
model.add(layers.Dense(neurons_l1))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(Dropout(0.25))
model.add(layers.Dense(neurons_l2))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(layers.Dense(neurons_l3))
model.add(BatchNormalization())
model.add(LeakyReLU())
model.add(Dropout(0.5))
model.add(layers.Dense(num_classes,activation='softmax'))
model.compile(
              optimizer="adam", # any optimizer works well, adam is a standard choice for simple problems
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), # loss function for classification = crossentropy
              metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 30, 30, 32)        896
#
#  batch_normalization_18 (Bat  (None, 30, 30, 32)       128
#  chNormalization)
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 30, 30, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 64)        18496
#
#  batch_normalization_19 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 14, 14, 64)        0
#
#  conv2d_11 (Conv2D)          (None, 6, 6, 128)         73856
#
#  batch_normalization_20 (Bat  (None, 6, 6, 128)        512
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 6, 6, 128)         0
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 6, 6, 128)         0
#
#  flatten_3 (Flatten)         (None, 4608)              0
#
#  dense_12 (Dense)            (None, 600)               2765400
#
#  batch_normalization_21 (Bat  (None, 600)              2400
#  chNormalization)
#
#  leaky_re_lu_21 (LeakyReLU)  (None, 600)               0
#
#  dropout_10 (Dropout)        (None, 600)               0
#
#  dense_13 (Dense)            (None, 300)               180300
#
#  batch_normalization_22 (Bat  (None, 300)              1200
#  chNormalization)
#
#  leaky_re_lu_22 (LeakyReLU)  (None, 300)               0
#
#  dense_14 (Dense)            (None, 150)               45150
#
#  batch_normalization_23 (Bat  (None, 150)              600
#  chNormalization)
#
#  leaky_re_lu_23 (LeakyReLU)  (None, 150)               0
#
#  dropout_11 (Dropout)        (None, 150)               0
#
#  dense_15 (Dense)            (None, 10)                1510
#
# =================================================================
# Total params: 3,090,704
# Trainable params: 3,088,156
# Non-trainable params: 2,548
# _________________________________________________________________

# %% [markdown]
# ## Example of Training proccedure
#
#
# Let's now train our model for a few epochs

# %%
history = model.fit(x_train, y_train, epochs=n_epochs, batch_size=n_batch_size)
# Out:
# Epoch 1/25
# 196/196 [==============================] - 37s 182ms/step - loss: 1.6642 - accuracy: 0.4134
# Epoch 2/25
# 196/196 [==============================] - 36s 183ms/step - loss: 1.2482 - accuracy: 0.5556
# Epoch 3/25
# 196/196 [==============================] - 36s 181ms/step - loss: 1.0739 - accuracy: 0.6203
# Epoch 4/25
# 196/196 [==============================] - 37s 187ms/step - loss: 0.9601 - accuracy: 0.6639
# Epoch 5/25
# 196/196 [==============================] - 36s 186ms/step - loss: 0.8777 - accuracy: 0.6917
# Epoch 6/25
# 196/196 [==============================] - 35s 179ms/step - loss: 0.8132 - accuracy: 0.7160
# Epoch 7/25
# 196/196 [==============================] - 35s 179ms/step - loss: 0.7577 - accuracy: 0.7345
# Epoch 8/25
# 196/196 [==============================] - 53s 268ms/step - loss: 0.7044 - accuracy: 0.7522
# Epoch 9/25
# 196/196 [==============================] - 60s 309ms/step - loss: 0.6688 - accuracy: 0.7648
# Epoch 10/25
# 196/196 [==============================] - 46s 236ms/step - loss: 0.6191 - accuracy: 0.7814
# Epoch 11/25
# 196/196 [==============================] - 41s 211ms/step - loss: 0.5819 - accuracy: 0.7943
# Epoch 12/25
# 196/196 [==============================] - 40s 202ms/step - loss: 0.5496 - accuracy: 0.8079
# Epoch 13/25
# 196/196 [==============================] - 46s 236ms/step - loss: 0.5150 - accuracy: 0.8194
# Epoch 14/25
# 196/196 [==============================] - 45s 229ms/step - loss: 0.4861 - accuracy: 0.8287
# Epoch 15/25
# 196/196 [==============================] - 40s 205ms/step - loss: 0.4588 - accuracy: 0.8369
# Epoch 16/25
# 196/196 [==============================] - 41s 207ms/step - loss: 0.4307 - accuracy: 0.8478
# Epoch 17/25
# 196/196 [==============================] - 43s 221ms/step - loss: 0.4061 - accuracy: 0.8572
# Epoch 18/25
# 196/196 [==============================] - 43s 221ms/step - loss: 0.3783 - accuracy: 0.8668
# Epoch 19/25
# 196/196 [==============================] - 41s 208ms/step - loss: 0.3525 - accuracy: 0.8751
# Epoch 20/25
# 196/196 [==============================] - 38s 194ms/step - loss: 0.3374 - accuracy: 0.8797
# Epoch 21/25
# 196/196 [==============================] - 43s 220ms/step - loss: 0.3158 - accuracy: 0.8893
# Epoch 22/25
# 196/196 [==============================] - 44s 222ms/step - loss: 0.2969 - accuracy: 0.8957
# Epoch 23/25
# 196/196 [==============================] - 39s 201ms/step - loss: 0.2860 - accuracy: 0.8993
# Epoch 24/25
# 196/196 [==============================] - 42s 216ms/step - loss: 0.2675 - accuracy: 0.9042
# Epoch 25/25
# 196/196 [==============================] - 48s 244ms/step - loss: 0.2516 - accuracy: 0.9104

# %% [markdown]
# ## Evaluation
#
# To evulate our model we need to see how well it performs to unknown data (test set):

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 1.1500493288040161
# Test accuracy: 0.7046999931335449

# %%
predictions = model.predict(x_test)
predictions_binary = np.argmax(predictions, axis=1)
y_test_binary = np.transpose(y_test)

cr = classification_report(y_test[:,] , predictions_binary)
cm = confusion_matrix(y_test[:,] , predictions_binary)
print(cm)
print(cr)
# Out:
# 313/313 [==============================] - 3s 10ms/step
# [[748  33  34  14  18   3   4  27  41  78]
#  [ 14 760   3  10   0   3   5   3   7 195]
#  [ 84  10 514  70  94  78  43  80  13  14]
#  [ 23  18  37 531  59 198  25  67  10  32]
#  [ 20   7  33  42 623  50  23 181   9  12]
#  [  9   3  21 151  19 676   9  87   7  18]
#  [  8  10  25  82  43  43 741  17   1  30]
#  [ 13   9  15  28  23  46   3 836   3  24]
#  [ 68  63   2   8   3   4   3   7 719 123]
#  [ 18  35   1  11   3   2   3  20   8 899]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.75      0.75      1000
#            1       0.80      0.76      0.78      1000
#            2       0.75      0.51      0.61      1000
#            3       0.56      0.53      0.55      1000
#            4       0.70      0.62      0.66      1000
#            5       0.61      0.68      0.64      1000
#            6       0.86      0.74      0.80      1000
#            7       0.63      0.84      0.72      1000
#            8       0.88      0.72      0.79      1000
#            9       0.63      0.90      0.74      1000
#
#     accuracy                           0.70     10000
#    macro avg       0.72      0.70      0.70     10000
# weighted avg       0.72      0.70      0.70     10000

# %%
fig = plt.figure(figsize=(10,10))
for i in range(25):
    random_image = random.randint(1, 10000)
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[random_image])
    if class_names[int(y_test[random_image])] ==class_names[predictions_binary[random_image]]:
        plt.xlabel(class_names[int(y_test[random_image])] + " | " + class_names[predictions_binary[random_image]],color='green')
    else:
        plt.xlabel(class_names[int(y_test[random_image])] + " | " + class_names[predictions_binary[random_image]],color='red')
plt.suptitle(' test | predicted class')
fig.tight_layout(rect=[0, 0.09, 1, 1])
plt.show()
