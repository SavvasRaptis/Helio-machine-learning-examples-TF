# %% [markdown]
# # Initialization
#
# ## Importing libraries
#
# As a first step we load the different libraries we are going to use, in this simple example we only need tensorflow (keras) and numpy

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import backend as K
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense,Input
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import BatchNormalization,Dropout,Flatten, MaxPooling2D, Conv2D
from tensorflow.keras.layers import LeakyReLU,PReLU,ELU,ThresholdedReLU,ReLU
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Loading Data
#
# Next step is to actually load the Cifar10 database and perform some simple pre-process in order to introduce it to the neural network

# %%
# Parameters of the model 
num_classes = 10 # number of output class (1-9)

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data() # we load the data from keras.datsets library

# Normalize pixel values to be between 0 and 1
## Normalization ##
# Scale images to the [0, 1] range
x_train = x_train / 255 # images are encoded with up to 256 so to normalize from 0-1 we simply divide
x_test = x_test / 255

print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ## Visualize the dataset

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    random_image = random.randint(1, 50000)
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[random_image])
    plt.xlabel(class_names[y_train[random_image][0]])
plt.show()

# %% [markdown]
# ## Model related parameters
#
# Here we define hyperparameters that are going to be used in the model and training below

# %%
n_epochs = 25 # Number of epochs, where 1 epoch = 1 use of the training set
n_batch_size = 256 # how many inputs are going to be used at the same time during one epoch. 
# note: small batch size can make the training faster but can make the generalization harder to achieve (less variety in sample)

neurons_conv2d1 = 32
kernel_size_conv2d1 = (3,3)
neurons_conv2d2 = 64
kernel_size_conv2d2 = (3,3)
neurons_conv2d3 = 128
kernel_size_conv2d3 = (3,3)
default_pool_size = (2,2)

# number of neurons for the 1 hidden layers
neurons_l1 = 128

# %%
#model = keras.Sequential()
#model.add(Conv2D(neurons_conv2d1,kernel_size=kernel_size_conv2d1, activation ="relu",input_shape=(32, 32, 3))) # obtaining features from image
#model.add(MaxPooling2D(pool_size=default_pool_size)) # reducing dimensionality
#model.add(Conv2D(neurons_conv2d2,kernel_size_conv2d2, activation ="relu"))
#model.add(MaxPooling2D(pool_size=default_pool_size))
#model.add(Conv2D(neurons_conv2d2,kernel_size_conv2d2, activation ="relu"))
#model.add(layers.Flatten())
#model.add(layers.Dense(64, activation='relu'))
#model.add(layers.Dense(num_classes,activation='softmax'))
#model.compile(
#              optimizer="adam", # any optimizer works well, adam is a standard choice for simple problems
#              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), # loss function for classification = crossentropy
#              metrics=["accuracy"])

# %%
model = keras.Sequential()
model.add(Conv2D(neurons_conv2d1,kernel_size=kernel_size_conv2d1,input_shape=(32, 32, 3))) # obtaining features from image
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=Alpha))
model.add(Conv2D(neurons_conv2d2,kernel_size_conv2d2, strides =2))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=Alpha))
model.add(Conv2D(neurons_conv2d3,kernel_size_conv2d3, strides =2))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(LeakyReLU(alpha=Alpha))
model.add(layers.Flatten())
model.add(layers.Dense(600))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=Alpha))
model.add(Dropout(0.25))
model.add(layers.Dense(300))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=Alpha))
model.add(layers.Dense(150))
model.add(BatchNormalization())
model.add(LeakyReLU(alpha=Alpha))
model.add(Dropout(0.5))
model.add(layers.Dense(num_classes,activation='softmax'))
model.compile(
              optimizer="adam", # any optimizer works well, adam is a standard choice for simple problems
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), # loss function for classification = crossentropy
              metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential_59"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_187 (Conv2D)         (None, 30, 30, 32)        896
#
#  batch_normalization_104 (Ba  (None, 30, 30, 32)       128
#  tchNormalization)
#
#  leaky_re_lu_175 (LeakyReLU)  (None, 30, 30, 32)       0
#
#  conv2d_188 (Conv2D)         (None, 14, 14, 64)        18496
#
#  batch_normalization_105 (Ba  (None, 14, 14, 64)       256
#  tchNormalization)
#
#  leaky_re_lu_176 (LeakyReLU)  (None, 14, 14, 64)       0
#
#  conv2d_189 (Conv2D)         (None, 6, 6, 128)         73856
#
#  batch_normalization_106 (Ba  (None, 6, 6, 128)        512
#  tchNormalization)
#
#  dropout_51 (Dropout)        (None, 6, 6, 128)         0
#
#  leaky_re_lu_177 (LeakyReLU)  (None, 6, 6, 128)        0
#
#  flatten_45 (Flatten)        (None, 4608)              0
#
#  dense_112 (Dense)           (None, 600)               2765400
#
#  batch_normalization_107 (Ba  (None, 600)              2400
#  tchNormalization)
#
#  leaky_re_lu_178 (LeakyReLU)  (None, 600)              0
#
#  dropout_52 (Dropout)        (None, 600)               0
#
#  dense_113 (Dense)           (None, 300)               180300
#
#  batch_normalization_108 (Ba  (None, 300)              1200
#  tchNormalization)
#
#  leaky_re_lu_179 (LeakyReLU)  (None, 300)              0
#
#  dense_114 (Dense)           (None, 150)               45150
#
#  batch_normalization_109 (Ba  (None, 150)              600
#  tchNormalization)
#
#  leaky_re_lu_180 (LeakyReLU)  (None, 150)              0
#
#  dropout_53 (Dropout)        (None, 150)               0
#
#  dense_115 (Dense)           (None, 10)                1510
#
# =================================================================
# Total params: 3,090,704
# Trainable params: 3,088,156
# Non-trainable params: 2,548
# _________________________________________________________________

# %% [markdown]
# ## Example of Training proccedure
#
#
# Let's now train our model for a few epochs

# %%
history = model.fit(x_train, y_train, epochs=n_epochs, batch_size=n_batch_size)
# Out:
# Epoch 1/25
# 196/196 [==============================] - 41s 204ms/step - loss: 1.6141 - accuracy: 0.4345
# Epoch 2/25
# 196/196 [==============================] - 37s 187ms/step - loss: 1.1983 - accuracy: 0.5749
# Epoch 3/25
# 196/196 [==============================] - 36s 181ms/step - loss: 1.0092 - accuracy: 0.6463
# Epoch 4/25
# 196/196 [==============================] - 39s 200ms/step - loss: 0.8909 - accuracy: 0.6892
# Epoch 5/25
# 196/196 [==============================] - 38s 192ms/step - loss: 0.8022 - accuracy: 0.7191
# Epoch 6/25
# 196/196 [==============================] - 53s 269ms/step - loss: 0.7337 - accuracy: 0.7445
# Epoch 7/25
# 196/196 [==============================] - 50s 254ms/step - loss: 0.6711 - accuracy: 0.7652
# Epoch 8/25
# 142/196 [====================>.........] - ETA: 13s - loss: 0.6059 - accuracy: 0.7876

# %% [markdown]
# ## Evaluation
#
# To evulate our model we need to see how well it performs to unknown data (test set):

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# C:\Users\Savva\miniconda3_2022\envs\ML_tensor\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# Test loss: 2.3047351837158203
# Test accuracy: 0.07980000227689743

# %%
predictions = model.predict(x_test)
predictions_binary = np.argmax(predictions, axis=1)
y_test_binary = np.transpose(y_test)

cr = classification_report(y_test[:,] , predictions_binary)
cm = confusion_matrix(y_test[:,] , predictions_binary)
print(cm)
print(cr)
# Out:
# 313/313 [==============================] - 5s 16ms/step
# [[  0  17   6   0  35   0 283 514  11 134]
#  [  0  42   9   1  26   0 242 509  38 133]
#  [  0  42   7   0  25   0 218 589  11 108]
#  [  0  59  16   0  14   1 228 493  15 174]
#  [  0  27   5   0  23   0 207 566  13 159]
#  [  0  48  10   0  17   2 210 549  13 151]
#  [  0  30   6   0  13   0 151 622   3 175]
#  [  0  82  19   0  29   1 279 417  30 143]
#  [  0  19   6   0  48   0 177 541  20 189]
#  [  0  60   7   0  48   0 304 410  35 136]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1000
#            1       0.10      0.04      0.06      1000
#            2       0.08      0.01      0.01      1000
#            3       0.00      0.00      0.00      1000
#            4       0.08      0.02      0.04      1000
#            5       0.50      0.00      0.00      1000
#            6       0.07      0.15      0.09      1000
#            7       0.08      0.42      0.13      1000
#            8       0.11      0.02      0.03      1000
#            9       0.09      0.14      0.11      1000
#
#     accuracy                           0.08     10000
#    macro avg       0.11      0.08      0.05     10000
# weighted avg       0.11      0.08      0.05     10000
# C:\Users\Savva\miniconda3_2022\envs\ML_tensor\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Savva\miniconda3_2022\envs\ML_tensor\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Savva\miniconda3_2022\envs\ML_tensor\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
